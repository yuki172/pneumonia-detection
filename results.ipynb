# %%
import matplotlib.pyplot as plt

# %%
# %run pneumonia_model.py
# %run config.py

# %%
model_path = "trained/Resnet50Model2-adam-0.0001-64-20-augment/epoch_19/model.pth"

# %%
model = PneumoniaModel(model_path)

# %%
image_path = "data/test/0_PNEUMONIA/person19_virus_50.jpeg"

# %%
visualization, pred_label, original_image = model.predict(image_path)

# %%
fig = plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(original_image.permute(1, 2, 0))
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(visualization)
plt.axis("off")
# plt.show()
plt.suptitle(f"Predicted {CLASSES[pred_label]}")
# Out:
# Text(0.5, 0.98, 'Predicted Pneumonia')

# %%
original_image
# Out:
# tensor([[[0.4078, 0.4000, 0.3961,  ..., 0.3961, 0.4235, 0.4000],
#          [0.4039, 0.3882, 0.3882,  ..., 0.4000, 0.4157, 0.4078],
#          [0.4118, 0.3961, 0.4000,  ..., 0.4039, 0.4078, 0.4000],
#          ...,
#          [0.7176, 0.7137, 0.7059,  ..., 0.6275, 0.6157, 0.6039],
#          [0.7176, 0.7098, 0.7176,  ..., 0.6235, 0.6196, 0.6118],
#          [0.7137, 0.7020, 0.7020,  ..., 0.6353, 0.6157, 0.6196]],
#
#         [[0.4078, 0.4000, 0.3961,  ..., 0.3961, 0.4235, 0.4000],
#          [0.4039, 0.3882, 0.3882,  ..., 0.4000, 0.4157, 0.4078],
#          [0.4118, 0.3961, 0.4000,  ..., 0.4039, 0.4078, 0.4000],
#          ...,
#          [0.7176, 0.7137, 0.7059,  ..., 0.6275, 0.6157, 0.6039],
#          [0.7176, 0.7098, 0.7176,  ..., 0.6235, 0.6196, 0.6118],
#          [0.7137, 0.7020, 0.7020,  ..., 0.6353, 0.6157, 0.6196]],
#
#         [[0.4078, 0.4000, 0.3961,  ..., 0.3961, 0.4235, 0.4000],
#          [0.4039, 0.3882, 0.3882,  ..., 0.4000, 0.4157, 0.4078],
#          [0.4118, 0.3961, 0.4000,  ..., 0.4039, 0.4078, 0.4000],
#          ...,
#          [0.7176, 0.7137, 0.7059,  ..., 0.6275, 0.6157, 0.6039],
#          [0.7176, 0.7098, 0.7176,  ..., 0.6235, 0.6196, 0.6118],
#          [0.7137, 0.7020, 0.7020,  ..., 0.6353, 0.6157, 0.6196]]])

# %%
from PIL import Image
image = Image.fromarray((original_image.numpy()) * 255).astype(np.uint8)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/data/lib/python3.11/site-packages/PIL/Image.py:3277, in fromarray(obj, mode)
#    3276 try:
# -> 3277     mode, rawmode = _fromarray_typemap[typekey]
#    3278 except KeyError as e:
#
# KeyError: ((1, 1, 224), '<f4')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 from PIL import Image
# ----> 2 image = Image.fromarray((original_image.numpy()) * 255).astype(np.uint8)
#
# File ~/miniconda3/envs/data/lib/python3.11/site-packages/PIL/Image.py:3281, in fromarray(obj, mode)
#    3279         typekey_shape, typestr = typekey
#    3280         msg = f"Cannot handle this data type: {typekey_shape}, {typestr}"
# -> 3281         raise TypeError(msg) from e
#    3282 else:
#    3283     rawmode = mode
#
# TypeError: Cannot handle this data type: (1, 1, 224), <f4

# %%
plt.imshow(original_image.permute(1, 2, 0).numpy())

# %%
visualization.shape
# Out:
# (224, 224, 3)

# %%
torch.save(model.model.state_dict(), "best_model.pth")

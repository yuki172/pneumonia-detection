# %%
import matplotlib.pyplot as plt

# %%
# %run pneumonia_model.py
# %run config.py

# %%
model_path = "trained/Resnet50Model2-adam-0.0001-64-20-augment/epoch_19/model.pth"

# %%
model = PneumoniaModel(model_path)

# %%
image_path = "data/test/0_PNEUMONIA/person1_virus_9.jpeg"

# %%
visualization, pred_label, original_image = model.predict(image_path)

# %%
fig = plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(original_image.permute(1, 2, 0))
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(visualization)
plt.axis("off")
# plt.show()
plt.suptitle(f"Predicted {CLASSES[pred_label]}")
# Out:
# Text(0.5, 0.98, 'Predicted Pneumonia')

# %%
pip install fastapi
# Out:
# Requirement already satisfied: fastapi in /Users/yzhang/miniconda3/envs/data/lib/python3.11/site-packages (0.116.1)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /Users/yzhang/miniconda3/envs/data/lib/python3.11/site-packages (from fastapi) (0.47.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /Users/yzhang/miniconda3/envs/data/lib/python3.11/site-packages (from fastapi) (2.11.9)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/yzhang/miniconda3/envs/data/lib/python3.11/site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/yzhang/miniconda3/envs/data/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/yzhang/miniconda3/envs/data/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/yzhang/miniconda3/envs/data/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/yzhang/miniconda3/envs/data/lib/python3.11/site-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.4.0)
# Requirement already satisfied: idna>=2.8 in /Users/yzhang/miniconda3/envs/data/lib/python3.11/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /Users/yzhang/miniconda3/envs/data/lib/python3.11/site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
